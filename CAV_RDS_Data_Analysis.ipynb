# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud, STOPWORDS

ps = PorterStemmer()
stop_words = set(stopwords.words('english'))

# %%
corpus_data = pd.read_csv('apple vision pro corpus.txt', delimiter="\t")
# corpus_comments = corpus_data['comments']
len(corpus_data)
# Out:
# 1200

# %%
def text_analysis(corpus):
  corpus_data = pd.read_csv(corpus, delimiter="\t")
  corpus_comments = corpus_data['comments']
  # corpus_comments_strings = str(corpus_comments)
  corpus_comments = list(corpus_comments)
  tokens = nltk.tokenize.word_tokenize(str(corpus_comments))
  corpus_tokens = nltk.tokenize.word_tokenize(str(corpus_comments))
  tokens = [word for word in tokens if word.isalpha()]
  tokens = [word for word in tokens if word not in set(stopwords.words('english'))]
  freq_dist = nltk.FreqDist(tokens)
  freq_dist.plot(40, cumulative=True)
  corpus_text = nltk.Text(str(corpus_comments))
  print('\n')
  freq_dist.tabulate(10)
  print(f'\n Amount of Words: {len(tokens)}')
  print(f'\n Lexical Diversity: {len(tokens)/len(set(str(tokens)))}')
  print(f'\n Vocabulary: {list(freq_dist.keys())}')
  print(f'\n Vocabulary Size: {len(list(freq_dist.keys()))}')
  print('\n')
  print('\n')
  print('\n')
  #print(corpus_comments_clean[:-2])
  wordcloud = WordCloud(width = 1400,
                      height = 800,
                      stopwords = stop_words,
                      min_font_size = 12,
                      random_state=1,
                      collocations=True,
                      colormap='cividis').generate(' '.join(corpus_tokens))
  plt.figure(figsize = (10, 6), facecolor = None)
  plt.imshow(wordcloud, interpolation='bilinear')
  plt.savefig(f'wordcloud {corpus}.png', format='png', dpi=150, bbox_inches='tight')
  plt.axis('off')
  plt.show()

# %%
text_analysis('apple vision pro corpus.txt')
# Out:
#   like vision    pro  apple  video  would    see    get     il    way
#    148    140    112    104     92     80     76     72     72     64
#
#  Amount of Words: 12128
#
#  Lexical Diversity: 391.2258064516129
#
#  Vocabulary: ['one', 'absolutely', 'mortified', 'last', 'sane', 'person', 'earth', 'glass', 'trunk', 'sony', 'hink', 'came', 'exciting', 'apple', 'hate', 'reflect', 'many', 'products', 'sombody', 'know', 'play', 'video', 'side', 'youtube', 'app', 'without', 'premium', 'subscription', 'decade', 'walking', 'around', 'functional', 'well', 'engineered', 'e', 'h', 'buy', 'vision', 'pro', 'get', 'k', 'likes', 'good', 'collaborate', 'using', 'pros', 'thinking', 'editor', 'client', 'like', 'immersive', 'screensharing', 'room', 'thumbnail', 'wrong', 'check', 'ad', 'right', 'saw', 'review', 'marquee', 'sounds', 'much', 'paid', 'placement', 'lame', 'product', 'could', 'hardly', 'considered', 'prototype', 'heads', 'unpluging', 'isnt', 'way', 'turn', 'iphone', 'display', 'headset', 'slide', 'fingers', 'press', 'hold', 'left', 'power', 'button', 'top', 'shutter', 'videos', 'missed', 'cool', 'move', 'end', 'put', 'said', 'goodbye', 'us', 'pinched', 'two', 'together', 'close', 'window', 'incredibly', 'useful', 'use', 'case', 'communication', 'speak', 'written', 'dictionary', 'type', 'thing', 'select', 'words', 'eyes', 'guestures', 'added', 'winks', 'eyebrow', 'lifts', 'custom', 'ai', 'model', 'learn', 'habits', 'speaking', 'allow', 'imagine', 'fairly', 'quick', 'communicating', 'thought', 'somebody', 'else', 'idea', 'reading', 'count', 'monte', 'cristo', 'character', 'named', 'nortier', 'paralytic', 'communicates', 'reason', 'dual', 'strap', 'want', 'squeezed', 'weight', 'reduction', 'report', 'common', 'sense', 'understand', 'device', 'evolve', 'usher', 'practical', 'utility', 'time', 'progresses', 'seen', 'novel', 'high', 'tech', 'toy', 'fitting', 'juveniles', 'marques', 'says', 'best', 'iv', 'todays', 'makes', 'feel', 'something', 'better', 'maybeeeee', 'future', 'lol', 'also', 'courtside', 'games', 'things', 'available', 'deals', 'leagues', 'subscriptions', 'virtual', 'tickets', 'heard', 'concerts', 'thanks', 'info', 'amazing', 'buying', 'tested', 'pico', 'quest', 'sorry', 'wow', 'testing', 'disappointed', 'expensive', 'need', 'fans', 'lose', 'connection', 'god', 'features', 'run', 'away', 'would', 'cameras', 'sensors', 'magnets', 'electro', 'radiation', 'projected', 'directly', 'strapped', 'skull', 'brain', 'never', 'fail', 'spectacularly', 'n', 'meta', 'similar', 'nothing', 'new', 'comment', 'looking', 'scary', 'fun', 'think', 'always', 'google', 'supposed', 'years', 'later', 'got', 'huge', 'snow', 'goggles', 'rich', 'explanation', 'extraordinary', 'bro', 'problem', 'pair', 'affordable', 'designed', 'created', 'simple', 'purpose', 'consciousness', 'humans', 'trapping', 'stream', 'found', 'within', 'certain', 'methodologies', 'lure', 'various', 'individuals', 'evil', 'world', 'wants', 'living', 'completely', 'disconnected', 'nature', 'reality', 'real', 'wiorld', 'digital', 'control', 'anyone', 'stay', 'hell', 'technology', 'least', 'homework', 'devices', 'told', 'wake', 'humanity', 'damage', 'looks', 'wish', 'try', 'playstation', 'vr', 'playing', 'enough', 'anxiously', 'wait', 'chip', 'implanted', 'watching', 'madan', 'gowri', 'channel', 'vlog', 'forward', 'air', 'crystal', 'clear', 'helped', 'lot', 'decide', 'purchase', 'people', 'ridiculous', 'someone', 'please', 'courtesy', 'help', 'make', 'second', 'towards', 'shot', 'stupid', 'hope', 'next', 'segway', 'flop', 'great', 'multitasting', 'desk', 'work', 'soo', 'excited', 'poeple', 'knowing', 'hands', 'kind', 'learning', 'keys', 'wonder', 'might', 'cause', 'headaches', 'suffering', 'migraine', 'robbing', 'store', 'mask', 'hide', 'identity', 'tf', 'christmas', 'sure', 'go', 'bang', 'happen', 'fascinating', 'ponder', 'possibilities', 'emerging', 'technologies', 'computer', 'interfaces', 'advanced', 'artificial', 'intelligence', 'bring', 'even', 'infancy', 'inhabit', 'realities', 'tailored', 'entirely', 'desires', 'fulfilling', 'dreams', 'becoming', 'sports', 'legend', 'beloved', 'celebrity', 'experiencing', 'life', 'free', 'troubles', 'current', 'society', 'potential', 'seems', 'boundless' ...
#
#  Vocabulary Size: 1480

# %%
def likes(text,amount,direction):
  data = pd.read_csv(text)
  data_frame = pd.DataFrame(data)
  by_likes = data_frame.loc[:, ['amount_of_likes', 'comment']].drop_duplicates().sort_values(by='amount_of_likes', ascending=direction, ignore_index=True)[:amount]
  return by_likes

# %%
likes('apple vision pro corpus likes.txt', 10, False)
# Out:
#    amount_of_likes                                            comment
# 0            21497  Happy to help film this one! Please don’t ever...
# 1                3  expensive price, and the floating screens stil...
# 2                2                       Start of something legendary
# 3                2                                     craaaaaaaaaaap
# 4                2                              what a waste of money
# 5                2  I'll see you guys in 3 years when we get recom...
# 6                2                           Wow this looks so cool 😮
# 7                1  Someone please save us from this insanity. Yes...
# 8                1  We will all be wearing advanced versions of th...
# 9                1  That is about as anti Apple Vision Pro as it c...

# %%
text_analysis('meta quest 3 corpus.txt')
# Out:
#   quest      vr    like headset     get   would   games     new     buy     one
#     680     292     224     200     164     160     160     136     136     132
#
#  Amount of Words: 20232
#
#  Lexical Diversity: 652.6451612903226
#
#  Vocabulary: ['get', 'things', 'size', 'pair', 'sunglasses', 'misplaced', 'screen', 'many', 'windows', 'apps', 'mac', 'would', 'work', 'like', 'multiple', 'displays', 'connected', 'normally', 'saw', 'clip', 'video', 'ben', 'shapiro', 'review', 'believe', 'https', 'youtu', 'th', 'afak', 'gsc', 'jesus', 'wept', 'worlds', 'left', 'conquer', 'people', 'different', 'vision', 'pros', 'share', 'movie', 'playing', 'simultaneously', 'l', 'text', 'pro', 'clear', 'sharp', 'shit', 'cool', 'bro', 'lot', 'real', 'sure', 'see', 'guys', 'years', 'recommended', 'watch', 'think', 'old', 'got', 'nice', 'presentation', 'however', 'new', 'iphone', 'replaced', 'longtime', 'driving', 'crazy', 'nothing', 'way', 'used', 'hate', 'fun', 'motion', 'sickness', 'hours', 'done', 'dumb', 'someone', 'wearing', 'giant', 'goggle', 'room', 'weirdo', 'thing', 'gon', 'na', 'cause', 'accidents', 'using', 'magic', 'trackpad', 'yet', 'support', 'wireless', 'mice', 'wish', 'future', 'walls', 'sync', 'devices', 'content', 'tv', 'together', 'e', 'g', 'tylenol', 'dd', 'need', 'recording', 'screens', 'everywhere', 'want', 'returned', 'mine', 'couple', 'days', 'justify', 'price', 'point', 'especially', 'barely', 'competitors', 'really', 'vr', 'go', 'meta', 'imo', 'teasing', 'ta', 'say', 'wow', 'amazing', 'death', 'humanity', 'turn', 'setting', 'translucent', 'another', 'bedroom', 'open', 'living', 'actually', 'desktop', 'also', 'youtube', 'anything', 'problem', 'play', 'videos', 'floating', 'still', 'jiggle', 'ass', 'product', 'dystopian', 'literally', 'entire', 'book', 'made', 'bad', 'idea', 'question', 'posible', 'computer', 'obviously', 'mean', 'make', 'connect', 'advanced', 'process', 'something', 'steam', 'basically', 'take', 'back', 'joe', 'bidens', 'broke', 'utopia', 'dirty', 'give', 'income', 'away', 'taxes', 'regarding', 'anybody', 'tell', 'please', 'seeing', 'blurry', 'edges', 'reality', 'part', 'looked', 'quest', 'kind', 'opinion', 'near', 'interact', 'example', 'ur', 'chair', 'scrolling', 'thru', 'n', 'u', 'music', 'window', 'backright', 'wall', 'press', 'could', 'certain', 'amount', 'distance', 'range', 'cuts', 'wat', 'nan', 'usually', 'apple', 'call', 'whatever', 'buy', 'know', 'dude', 'went', 'pornhub', 'x', 'others', 'ha', 'come', 'anyone', 'great', 'beyond', 'weird', 'looks', 'guess', 'ppl', 'wan', 'games', 'useful', 'unlike', 'random', 'tits', 'skateboarding', 'busy', 'streets', 'worse', 'sat', 'behind', 'tesla', 'autopilot', 'unnecessary', 'simple', 'man', 'blew', 'park', 'buddy', 'good', 'job', 'noticed', 'playlist', 'following', 'better', 'huge', 'pricetag', 'even', 'close', 'maybe', 'harming', 'eyes', 'everyday', 'shouldve', 'gone', 'building', 'car', 'relevant', 'thus', 'money', 'gain', 'catch', 'wasnt', 'staged', 'lol', 'neat', 'sci', 'fi', 'bullshit', 'adds', 'wait', 'till', 'contacts', 'silly', 'instead', 'android', 'phone', 'af', 'imagine', 'remove', 'shocked', 'world', 'already', 'asked', 'pin', 'around', 'home', 'crib', 'speakers', 'monitors', 'etc', 'glasses', 'worth', 'whopping', 'k', 'technology', 'puts', 'player', 'one', 'vibes', 'stupid', 'walking', 'paying', 'much', 'gadget', 'makes', 'look', 'fake', 'legendary', 'special', 'essentially', 'putting', 'reverse', 'green', 'surroundings', 'kinda', 'pointless', 'gives', 'strong', 'damned', 'best', 'use', 'ever', 'seen', 'pc', 'setups', 'insane', 'device', 'potentially', 'replace', 'bite', 'apples', 'net', 'right', 'face', 'hurts', 'neck', 'costs', 'loser', 'trying', 'promote', 'bored', 'head', 'dent', 'human', 'evolution', 'scares', 'looking', 'pretty', 'keyboard', 'mouse', 'physical', 'possible', 'virtual', 'mind', 'blown', 'showed', 'trajectory', 'speed', 'ball', 'exploded', 'pins', 'roughly', 'monitor', 'positioned', 'wonder', 'move', 'closer', 'built', 'angled', 'slightly', 'tempted', 'put', 'far', 'btw', 'experience', 'oculus', 'waste', 'end', 'reasons', 'porn', 'offended', 'saying', 'walk', 'waiting', 'original', 'goes', 'beta', 'caveat', 'wear', 'headset', 'day', 'araound', 'relax', 'ex ...
#
#  Vocabulary Size: 1894

# %%
# likes('apple_vision_pro_two.txt', 10, False)

# %%
text_analysis('psvr corpus.txt')
# Out:
#      vr    psvr   games   quest      ps    like    play    sony headset    game
#     700     620     590     358     280     266     206     206     204     202
#
#  Amount of Words: 26626
#
#  Lexical Diversity: 858.9032258064516
#
#  Vocabulary: ['watch', 'vr', 'videos', 'youtube', 'hat', 'honestly', 'walk', 'round', 'house', 'bobble', 'thing', 'absolutely', 'hate', 'cant', 'play', 'ro', 'blox', 'tip', 'wearing', 'wroung', 'lol', 'strap', 'back', 'head', 'around', 'neck', 'line', 'opportunity', 'experience', 'best', 'get', 'married', 'days', 'used', 'friend', 'mine', 'would', 'move', 'lean', 'left', 'right', 'playing', 'top', 'gear', 'snes', 'laugh', 'psvr', 'legitimate', 'reason', 'backwards', 'compatible', 'im', 'buy', 'ps', 'money', 'owned', 'v', 'played', 'times', 'never', 'k', 'event', 'full', 'hd', 'done', 'thank', 'nsync', 'either', 'bought', 'bit', 'motion', 'sickness', 'like', 'min', 'gt', 'amazing', 'less', 'beat', 'saber', 'love', 'game', 'dance', 'swing', 'arms', 'horizon', 'gave', 'worst', 'feeling', 'standing', 'problem', 'going', 'fall', 'gon', 'na', 'take', 'breaks', 'wife', 'got', 'one', 'christmas', 'fun', 'think', 'technology', 'quite', 'yet', 'minutes', 'lot', 'nausea', 'headaches', 'video', 'know', 'really', 'want', 'playstation', 'headset', 'sure', 'vote', 'trump', 'definitely', 'looking', 'buying', 'two', 'ppl', 'simultaneously', 'console', 'unit', 'years', 'old', 'games', 'still', 'awesome', 'review', 'mode', 'using', 'steering', 'madden', 'fucking', 'product', 'uses', 'description', 'sony', 'fucked', 'controllers', 'last', 'hours', 'tops', 'good', 'kid', 'hitting', 'pros', 'go', 'realistic', 'expectations', 'amazed', 'sm', 'see', 'meta', 'quest', 'need', 'work', 'answer', 'yes', 'worth', 'second', 'hand', 'biggest', 'lack', 'directional', 'keys', 'normal', 'controller', 'since', 'software', 'must', 'written', 'compensate', 'find', 'approaches', 'tedious', 'confusing', 'time', 'consuming', 'little', 'heavy', 'however', 'may', 'considered', 'somewhat', 'plus', 'stop', 'away', 'personal', 'wear', 'hearing', 'aides', 'ear', 'inserts', 'nice', 'hear', 'comments', 'use', 'l', 'device', 'easy', 'learning', 'month', 'everyone', 'try', 'early', 'make', 'return', 'returning', 'stand', 'liked', 'enough', 'keep', 'meant', 'personally', 'bad', 'enjoy', 'cheesy', 'movie', 'theater', 'came', 'wireless', 'look', 'compatibility', 'beyond', 'insanity', 'especially', 'starved', 'content', 'understand', 'earth', 'heads', 'executives', 'behind', 'decision', 'without', 'arm', 'opinion', 'brings', 'reality', 'real', 'fast', 'xmas', 'envy', 'tend', 'topple', 'trying', 'unsure', 'passthrough', 'help', 'option', 'available', 'plan', 'much', 'better', 'oculus', 'also', 'cool', 'surly', 'takes', 'win', 'next', 'rank', 'om', 'cousmonius', 'high', 'thorough', 'fella', 'sound', 'advice', 'heb', 'het', 'toen', 'gekocht', 'en', 'ik', 'moet', 'echt', 'zeggen', 'speel', 'bijna', 'niks', 'meer', 'usb', 'c', 'kabel', 'je', 'stoppen', 'stelt', 'alles', 'keer', 'daarna', 'onthoud', 'de', 'speelruimte', 'dus', 'instellen', 'keren', 'erin', 'bril', 'opzetten', 'spelen', 'maar', 'haptics', 'trigger', 'weerstand', 'perfect', 'net', 'zoals', 'bij', 'dualsense', 'er', 'zitten', 'ook', 'zelf', 'als', 'bijvoorbeeld', 'tegen', 'een', 'auto', 'rijd', 'muur', 'dan', 'trilt', 'hoofd', 'mee', 'leuke', 'ervaring', 'super', 'comfortabel', 'gewicht', 'word', 'verdeeld', 'geweldig', 'zit', 'gevoel', 'van', 'snelheid', 'veel', 'beter', 'zien', 'alle', 'interieurs', 'gelikt', 'uit', 'apex', 'makkelijker', 'te', 'pakken', 'omdat', 'ziet', 'resident', 'evil', 'village', 'dit', 'spel', 'niet', 'normaal', 'mega', 'vet', 'loopt', 'op', 'plekken', 'waar', 'nooit', 'zou', 'willen', 'komen', 'red', 'matter', 'met', 'fantastische', 'graphics', 'goed', 'verhaal', 'schitterende', 'omgevingen', 'aanrader', 'vind', 'mooiste', 'minigolf', 'leuk', 'banen', 'goede', 'besturing', 'aan', 'midgetgolfen', 'bent', 'walking', 'dead', 'mooie', 'kunt', 'ei', 'kwijt', 'lekker', 'zombies', 'slachten', 'kayak', 'mooi', 'mensen', 'laten', 'hoe', 'eruit', 'relaxt', 'rond', 'varen', 'alleen', 'kijken', 'naar', 'dieren', 'vele', 'vissen', 'man', 'sky', 'zo', 'ze', 'schaling', 'hebben', 'gemaakt', 'lijkt', 'groot', 'la ...
#
#  Vocabulary Size: 2057

# %%
text_analysis('CAV-RDS Corpora.txt')
# Out:
#   quest      vr   games    psvr    like headset   would     get     one    play
#    1070    1032     766     652     638     444     436     386     376     326
#
#  Amount of Words: 58986
#
#  Lexical Diversity: 1902.774193548387
#
#  Vocabulary: ['one', 'absolutely', 'mortified', 'last', 'sane', 'person', 'earth', 'glass', 'trunk', 'sony', 'hink', 'came', 'exciting', 'apple', 'hate', 'reflect', 'many', 'products', 'sombody', 'know', 'play', 'video', 'side', 'youtube', 'app', 'without', 'premium', 'subscription', 'decade', 'walking', 'around', 'functional', 'well', 'engineered', 'e', 'h', 'buy', 'vision', 'pro', 'get', 'k', 'likes', 'good', 'collaborate', 'using', 'pros', 'thinking', 'editor', 'client', 'like', 'immersive', 'screensharing', 'room', 'thumbnail', 'wrong', 'check', 'ad', 'right', 'saw', 'review', 'marquee', 'sounds', 'much', 'paid', 'placement', 'lame', 'product', 'could', 'hardly', 'considered', 'prototype', 'heads', 'unpluging', 'isnt', 'way', 'turn', 'iphone', 'display', 'headset', 'slide', 'fingers', 'press', 'hold', 'left', 'power', 'button', 'top', 'shutter', 'videos', 'missed', 'cool', 'move', 'end', 'put', 'said', 'goodbye', 'us', 'pinched', 'two', 'together', 'close', 'window', 'incredibly', 'useful', 'use', 'case', 'communication', 'speak', 'written', 'dictionary', 'type', 'thing', 'select', 'words', 'eyes', 'guestures', 'added', 'winks', 'eyebrow', 'lifts', 'custom', 'ai', 'model', 'learn', 'habits', 'speaking', 'allow', 'imagine', 'fairly', 'quick', 'communicating', 'thought', 'somebody', 'else', 'idea', 'reading', 'count', 'monte', 'cristo', 'character', 'named', 'nortier', 'paralytic', 'communicates', 'reason', 'dual', 'strap', 'want', 'squeezed', 'weight', 'reduction', 'report', 'common', 'sense', 'understand', 'device', 'evolve', 'usher', 'practical', 'utility', 'time', 'progresses', 'seen', 'novel', 'high', 'tech', 'toy', 'fitting', 'juveniles', 'marques', 'says', 'best', 'iv', 'todays', 'makes', 'feel', 'something', 'better', 'maybeeeee', 'future', 'lol', 'also', 'courtside', 'games', 'things', 'available', 'deals', 'leagues', 'subscriptions', 'virtual', 'tickets', 'heard', 'concerts', 'thanks', 'info', 'amazing', 'buying', 'tested', 'pico', 'quest', 'sorry', 'wow', 'testing', 'disappointed', 'expensive', 'need', 'fans', 'lose', 'connection', 'god', 'features', 'run', 'away', 'would', 'cameras', 'sensors', 'magnets', 'electro', 'radiation', 'projected', 'directly', 'strapped', 'skull', 'brain', 'never', 'fail', 'spectacularly', 'n', 'meta', 'similar', 'nothing', 'new', 'comment', 'looking', 'scary', 'fun', 'think', 'always', 'google', 'supposed', 'years', 'later', 'got', 'huge', 'snow', 'goggles', 'rich', 'explanation', 'extraordinary', 'bro', 'problem', 'pair', 'affordable', 'designed', 'created', 'simple', 'purpose', 'consciousness', 'humans', 'trapping', 'stream', 'found', 'within', 'certain', 'methodologies', 'lure', 'various', 'individuals', 'evil', 'world', 'wants', 'living', 'completely', 'disconnected', 'nature', 'reality', 'real', 'wiorld', 'digital', 'control', 'anyone', 'stay', 'hell', 'technology', 'least', 'homework', 'devices', 'told', 'wake', 'humanity', 'damage', 'looks', 'wish', 'try', 'playstation', 'vr', 'playing', 'enough', 'anxiously', 'wait', 'chip', 'implanted', 'watching', 'madan', 'gowri', 'channel', 'vlog', 'forward', 'air', 'crystal', 'clear', 'helped', 'lot', 'decide', 'purchase', 'people', 'ridiculous', 'someone', 'please', 'courtesy', 'help', 'make', 'second', 'towards', 'shot', 'stupid', 'hope', 'next', 'segway', 'flop', 'great', 'multitasting', 'desk', 'work', 'soo', 'excited', 'poeple', 'knowing', 'hands', 'kind', 'learning', 'keys', 'wonder', 'might', 'cause', 'headaches', 'suffering', 'migraine', 'robbing', 'store', 'mask', 'hide', 'identity', 'tf', 'christmas', 'sure', 'go', 'bang', 'happen', 'fascinating', 'ponder', 'possibilities', 'emerging', 'technologies', 'computer', 'interfaces', 'advanced', 'artificial', 'intelligence', 'bring', 'even', 'infancy', 'inhabit', 'realities', 'tailored', 'entirely', 'desires', 'fulfilling', 'dreams', 'becoming', 'sports', 'legend', 'beloved', 'celebrity', 'experiencing', 'life', 'free', 'troubles', 'current', 'society', 'potential', 'seems', 'boundless' ...
#
#  Vocabulary Size: 3755

# %%
corpus_df = {
    'corpus name': ['apple vision corpus', 'meta quest 3 corpus', 'psvr corpus'],
    'token count': [12128, 20232, 26626],
    'lexical diversity': [391, 652, 858],
    'vocabulary size': [1480, 1894, 2057]
}

corpus_frame = pd.DataFrame(corpus_df)
corpus_frame
# Out:
#            corpus name  token count  lexical diversity  vocabulary size
# 0  apple vision corpus        12128                391             1480
# 1  meta quest 3 corpus        20232                652             1894
# 2          psvr corpus        26626                858             2057

# %%
# likes('apple_vision_pro_three.txt', 10, False)

# %%
# text_analysis('meta_quest_3_one_comments.txt')

# %%
# likes('meta_quest_3_one.txt', 10, False)

# %%
# text_analysis('meta_quest_3_two_comments.txt')

# %%
# likes('meta_quest_3_two.txt', 10, False)

# %%
# text_analysis('meta_quest_3_three_comments.txt')

# %%
# likes('meta_quest_3_three.txt', 10, False)

# %%
# text_analysis('psvr_one_comments.txt')

# %%
# likes('psvr_one.txt', 10, False)

# %%
# text_analysis('psvr_two_comments.txt')

# %%
# likes('psvr_two.txt', 10, False)

# %%
# text_analysis('psvr_three_comments.txt')

# %%
# likes('psvr_three.txt', 10, False)

# %%
# text_analysis('psvr_four_comments.txt')

# %%
# likes('psvr_four.txt', 10, False)
